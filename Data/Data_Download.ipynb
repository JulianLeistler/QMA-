# %%
import yfinance as yf
import pandas as pd
import numpy as np

tickers = ['AAPL', 'TSLA', 'MSFT', 'META', 'AMZN', 'GOOGL', 'NVDA']
benchmark_world_ticker = 'VT'
benchmark_risk_free_ticker = '^TNX'
benchmark_sp500_ticker = '^SPX'
benchmark_nasdaq_ticker = '^NDX'
start_date = "2012-05-18"
end_date = "2026-04-01"

# ==========================================
# 2. DATA LOADING (CACHED)
# ==========================================

data = yf.download(tickers, start=start_date, end=end_date, auto_adjust=False, progress=False)['Adj Close'].to_csv('data.csv')
bench_world = yf.download(benchmark_world_ticker, start=start_date, end=end_date, auto_adjust=False, progress=False)['Adj Close'].to_csv('bench_world.csv')
bench_rf = yf.download(benchmark_risk_free_ticker, start=start_date, end=end_date, auto_adjust=False, progress=False)['Adj Close'].to_csv('bench_rf.csv')
bench_sp500 = yf.download(benchmark_sp500_ticker, start=start_date, end=end_date, auto_adjust=False, progress=False)['Adj Close'].to_csv('bench_sp500.csv')
bench_nasdaq = yf.download(benchmark_nasdaq_ticker, start=start_date, end=end_date, auto_adjust=False, progress=False)['Adj Close'].to_csv('bench_nasdaq.csv')
dotcom = yf.download('^NDX', start="2000-04-01", end="2002-10-31", auto_adjust=False, progress=False)['Adj Close'].to_csv('dotcom.csv')
